# %% [markdown]
# # Cell Types Project
# *Replace this with the name of your project*

# %% [markdown]
# ## Team Member Names & Contributions
# *Feel free to name your team, but please also include your real names and IDs here. Please specify who in your group worked on which parts of the project.*
#
# - **Isabel Rodriguez A18552101**: You know, blowing up things and such.
# - **Ishika Nahar**: Cleverly sneaking into small spaces
# - **Emily McClung A18348146**: AKA The "Muscle"

# %% [markdown]
# ## Abstract

# %% [markdown]
# *Fill in your 3-4 sentence abstract here*

# %% [markdown]
# ## Research Question

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# # Background and Prior Work

# %% [markdown]
# *Fill in your background and prior work here (~500 words). You are welcome to use additional subheadings. You should also include a paragraph describing each dataset and how you'll be using them.*
#
# ### References (include links):
# (1)
#
# (2)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# *Fill in your hypotheses here*

# %% [markdown]
# ## Setup
# *To get started, we need to import necessary packages. These will assist us in creating visuals and making the data easier to analyze. Next we imported our data into a dataframe and displayed the first 5 rows. Dataset downloaded from INSERT HERE*

# %%
#necessary packages
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#importing the data
#genes = pd.read_csv('1b1sm_intCt.txt', sep = '\t') 
psmRNA = pd.read_csv('1b1sm_isoform_intCt.txt', sep = '\t')
psmRNA.set_index('transcript_id', inplace=True)
#display the first 5 rows
psmRNA.head()
# Out:
#                d225001.ex1.1S  d225002.ex1.1S  d225003.ex1.1B  d225005.ex1.1B  \
# transcript_id
# FBtr0081624               111              76               0              14
# FBtr0071763                 0               0               0               0
# FBtr0071764                 0               0               0               0
# FBtr0100521                 0               0               0               0
# FBtr0342981                 0               0               0               0
#
#                d225006.ex1.1B  d225007.ex1.1B  d225008.ex1.1B  d225009.ex1.1B  \
# transcript_id
# FBtr0081624                22              49               0              38
# FBtr0071763                 0               0               0               0
# FBtr0071764                 0               0               0               0
# FBtr0100521                 0               0               0               0
# FBtr0342981                 0               0               0               0
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Describe your data wrangling steps here.

# %%
#convert the data to log2 to scale the data
psmRNA_log = np.log2(psmRNA+1)

#Filter for the top 50 most varible genes
top_genes = psmRNA_log.var(axis=1).sort_values(ascending=False).head(50).index
psmRNA_subset = psmRNA_log.loc[top_genes]

#create and display heatmap
plt.figure(figsize=(20,10))
sns.heatmap(psmRNA_subset,
            cmap='coolwarm',
            xticklabels=True,
            yticklabels=True)
plt.title('Gene Expressions Heat Map (Log2)')
plt.xlabel('Samples')
plt.ylabel('Transcript ID')
plt.xticks(rotation=30)
plt.show()

sns.clustermap(psmRNA_subset,
            cmap='coolwarm',
            standard_scale=0,
            figsize=(12,12))
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /opt/conda/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
#want to take a deeper look at 0303125, 0331461,0081519, 0445670,0307597,0081426,0071519,034320,0089747, and the samples in the far right
#will pick the next plot based on our hypthesis 
#what is different about the M samples?
#look what about the samples ahd have high values in all genes?(middl eregion of clusterplot

# %% [markdown]
# ## Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
